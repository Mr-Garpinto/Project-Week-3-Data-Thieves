# %%
import pandas as pd
data = pd.read_csv("/Users/goncalopinto/Documents/GitHub/Project-Week-3-Data-Thieves/your-project/Hourly_Counts_Final.csv")
data
# Out:
#     Hour  Jun-29  Jun-30  Jul-01  Jul-02
# 0      0      79      70     270     127
# 1      1      64      68     217      90
# 2      2      66      77     208     108
# 3      3      92     132     199     103
# 4      4      65     134     168      96
# 5      5      54     108     128      96
# 6      6      77      68     146      98
# 7      7      63      87     191      87
# 8      8      54      69     161      76
# 9      9      68      80     110      74
# 10    10      76      96     141      68
# 11    11     103     108     160     113
# 12    12     123      94     173     107
# 13    13      97     129     192     130
# 14    14     136     195     165     147
# 15    15     116     196     224     171
# 16    16     125     180     229     165
# 17    17     133     212     225     181
# 18    18     155     244     197     176
# 19    19     123     659     202     348
# 20    20     124    2088     236     212
# 21    21     128     780     174     309
# ...

# %%
import matplotlib.pyplot as plt 

"""
x = [0.00001,0.001,0.01,0.1,0.5,1,5]
y = [0.945,0.885,0.893,0.9,0.996,1.25,1.19]
plt.xlim(0.00001,5)
plt.ylim(0.8,1.4)
plt.plot(x, y, marker='o', linestyle='--', color='r', 
label='Square') 
plt.xlabel('x')
plt.ylabel('y') 
plt.title('compare')
plt.legend() 
plt.show()

"""

x = data["Hour"]
y = data["Jun-29"]
yy = data["Jun-30"]
yyy = data["Jul-01"]
yyyy = data["Jul-02"]

plt.plot(x, y + yy)

# %%
plt.bar(data['Hour'],data['Jul-01'])
plt.show()

# %%
f = plt.figure(figsize = (15,15))
plt.plot(x, y)
plt.show()

# %%
f , (a1,a2, a3, a4) = plt.subplots(nrows = 1, ncols = 4, figsize = (20,10))


a1.plot(x, y)
a2.plot(x, yy)
a3.plot(x, yyy)
a4.plot(x, yyyy)

plt.show()

# %%
data_com = pd.read_excel('/Users/goncalopinto/Documents/GitHub/Project-Week-3-Data-Thieves/your-project/single_com_data.xls')

# %%
data_com
# Out:
#     Hour  T_C  Y-T  Unnamed: 3  A-T
# 0      0   79  NaN         NaN  NaN
# 1      1   64  NaN         NaN  NaN
# 2      2   66  NaN         NaN  NaN
# 3      3   92  NaN         NaN  NaN
# 4      4   65  NaN         NaN  NaN
# ..   ...  ...  ...         ...  ...
# 91    91  348  NaN         NaN  NaN
# 92    92  212  NaN         NaN  NaN
# 93    93  309  NaN         NaN  NaN
# 94    94  156  NaN         NaN  NaN
# 95    95  147  NaN         NaN  NaN
#
# [96 rows x 5 columns]

# %%
x = data_com["Hour"]
y = data_com["T_C"]
yy = data_com["Y-T"]
yyyy = data_com["A-T"]


plt.plot(x, yyyy)

# %%
f = plt.figure(figsize = (15,15))

plt.ylabel("User's")
plt.xlabel("Time")
plt.title('User engagement')



plt.plot(x, y, color = "deepskyblue", label='Twitter user engagement')
plt.plot(x, yy, color = "orangered", label = 'Youtube user engagement')
plt.plot(x, yyyy, color = "fuchsia", label = 'True user engagement (interception)')
plt.legend()
plt.show()

# %%
#advanced

data_adv = pd.read_excel('/Users/goncalopinto/Documents/GitHub/Project-Week-3-Data-Thieves/your-project/advanced.xls')

# %%
data_adv
# Out:
#    Hour   T_C    Y-T     A-T   BAD    GOOD  BBAD
# 0    41   212    NaN     NaN   NaN     NaN   NaN
# 1    42   244    NaN     NaN   NaN     NaN   NaN
# 2    43   659  141.0   400.0   8.0   392.0  -8.0
# 3    44  2088  471.0  1280.0  26.0  1254.0 -26.0
# 4    45   780  188.0   484.0  10.0   474.0 -10.0
# 5    46   452   94.0   273.0   5.0   268.0  -5.0
# 6    47   361   48.0   205.0   4.0   201.0  -4.0
# 7    48   270    NaN     NaN   NaN     NaN   NaN
# 8    49   217    NaN     NaN   NaN     NaN   NaN

# %%
x = data_adv["Hour"]
y = data_adv["T_C"]
yy = data_adv["Y-T"]
yyyy = data_adv["A-T"]
good = data_adv["GOOD"]
bad = data_adv["BAD"]
bbad = data_adv["BBAD"]


#plt.plot(x, y)
#plt.plot(x, yy)
#plt.plot(x, yyyy)
#plt.plot(x, good)
#plt.plot(x, bad)
f = plt.figure(figsize = (15,15))

plt.ylabel("Engagement")
plt.xlabel("Time")
plt.title('Engagement, PN-Response')

plt.bar(x, good, color = "turquoise", label = 'Positive engagement')
plt.bar(x, bbad, color = "crimson", label = 'Negative engagement')
plt.plot(x, yyyy, color = "orange", label = 'Total Engagement')


plt.legend()
plt.show()
#color=(0.2, 0.4, 0.6, 0.6)

# %%
f = plt.figure(figsize = (15,15))

plt.ylabel("User's")
plt.xlabel("Time")
plt.title('User engagement')

plt.plot(x, y, color = "deepskyblue", label='Twitter user engagement')
plt.plot(x, yy, color = "orangered", label = 'Youtube user engagement')
plt.plot(x, yyyy, color = "fuchsia", label = 'True user engagement (interception)')
plt.legend()
plt.show()

# %%
import pandas as pd

# %%
data_comm = pd.read_excel('/Users/goncalopinto/Documents/GitHub/Project-Week-3-Data-Thieves/your-project/tcom.xls')
data_commm = pd.read_excel('/Users/goncalopinto/Documents/GitHub/Project-Week-3-Data-Thieves/your-project/tcomm.xls')

# %%
data_comm
# Out:
#        Words  Amount
# 0       like     338
# 1    success     195
# 2       love     128
# 3    amazing      62
# 4    awesome      46
# 5   positive       3
# 6  excellent       7
# 7     genius       6
# 8  wonderful       6

# %%
x = data_comm["Amount"]
W = data_comm["Words"]
xb = data_commm["Amount"]
Wb = data_commm["Words"]

# %%
plt.plot(x, W, "ro")

plt.plot(xb, Wb,"bo")

plt.plot(x, W)

plt.plot(xb, Wb)
